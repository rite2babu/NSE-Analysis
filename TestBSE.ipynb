# %%
from bsedata.bse import BSE
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
def pprint(obj):
    pp.pprint(obj)

# %%
b = BSE()
print(b)
# Output:
# Driver Class for Bombay Stock Exchange (BSE)

# to execute "updateScripCodes" on instantiation
b = BSE(update_codes = True)
# Out:
# Driver Class for Bombay Stock Exchange (BSE)

# %%
q = b.getQuote('534976')
pprint(q)
# Out:
# {   '2WeekAvgQuantity': '0.01 Lakh',
#     '52weekHigh': '2864.95',
#     '52weekLow': '1591.00',
#     'buy': {   '1': {'price': '2049.20', 'quantity': '3'},
#                '2': {'price': '2049.15', 'quantity': '10'},
#                '3': {'price': '2049.05', 'quantity': '4'},
#                '4': {'price': '2048.25', 'quantity': '4'},
#                '5': {'price': '2048.05', 'quantity': '5'}},
#     'change': '-15.60',
#     'companyName': 'V-MART RETAIL LTD.',
#     'currentValue': '2053.95',
#     'dayHigh': '2056.95',
#     'dayLow': '2038.45',
#     'faceValue': '10.00',
#     'group': 'A  / S&P BSE 500',
#     'industry': 'Consumer Services',
#     'marketCapFreeFloat': '2,274.73 Cr.',
#     'marketCapFull': '4,062.02 Cr.',
#     'pChange': '-0.75',
#     'previousClose': '2069.55',
#     'previousOpen': '2054.90',
#     'scripCode': '534976',
#     'securityID': 'VMART',
#     'sell': {   '1': {'price': '2054.95', 'quantity': '13'},
#                 '2': {'price': '2055.00', 'quantity': '3'},
#                 '3': {'price': '2055.50', 'quantity': '3'},
#                 '4': {'price': '2055.95', 'quantity': '3'},
#                 '5': {'price': '2056.65', 'quantity': '5'}},
#     'totalTradedQuantity': '0.00 Lakh',
#     'totalTradedValue': '0.01 Cr.',
#     'updatedOn': '25 Jan 24 | 12:37 PM',
#     'weightedAvgPrice': '2050.44'}

# %%
codelist = ["500116", "512573"]
for code in codelist:
    quote = b.getQuote(code)
    pprint(quote["companyName"])
    pprint(quote["currentValue"])
    pprint(quote["updatedOn"])
# Out:
# 'IDBI BANK LTD.'
# '83.22'
# '25 Jan 24 | 12:38 PM'
# 'AVANTI FEEDS LTD.-$'
# '508.65'
# '25 Jan 24 | 12:38 PM'

# %%
l = b.topLosers()
# pprint(l)

# %%
b.getIndices(category='corporate')
# Out:
# {'updatedOn': '24 Jan 2024',
#  'indices': [{'currentValue': '234.10',
#    'change': '+0.02',
#    'pChange': '0.01',
#    'scripFlag': 'SPBINCPT',
#    'name': 'S&P BSE India Corporate Bond Index'},
#   {'currentValue': '234.80',
#    'change': '+0.04',
#    'pChange': '0.02',
#    'scripFlag': 'SPBINCFT',
#    'name': 'S&P BSE India Financials Bond Index'},
#   {'currentValue': '242.12',
#    'change': '+0.03',
#    'pChange': '0.01',
#    'scripFlag': 'SPBINCST',
#    'name': 'S&P BSE India Services Bond Index'},
#   {'currentValue': '245.28',
#    'change': '-0.03',
#    'pChange': '-0.01',
#    'scripFlag': 'SPBINCUT',
#    'name': 'S&P BSE India Utilities Bond Index'},
#   {'currentValue': '225.46',
#    'change': '-0.09',
#    'pChange': '-0.04',
#    'scripFlag': 'SPBINCIT',
#    'name': 'S&P BSE India Industrials Bond Index'}]}

# %%
d = b.getScripCodes()

# %%
# b.get
