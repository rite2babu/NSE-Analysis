# %%
## Use stk.ipynp to compute XIRR

# %%
import pandas as pd
from pathlib import Path

# %%
file_path = Path('C:\\Users\\111075866\\Downloads\\mf-13.csv')
mf = pd.read_csv(file_path)
mf.describe(include='all')
# mf.head()
#[['Scheme','Inv.Amt','Overall Gain','Inv.Date']]
# Out:
#                                    Scheme   Latest NAV      Change  \
# count                                 282   283.000000  283.000000
# unique                                 36          NaN         NaN
# top     ICICI Pru Multi-Asset Fund - D(G)          NaN         NaN
# freq                                   33          NaN         NaN
# mean                                  NaN   172.046648    0.427975
# std                                   NaN   261.656215    0.692349
# min                                   NaN    11.975200   -0.229000
# 25%                                   NaN    25.639000    0.027200
# 50%                                   NaN    29.966800    0.130400
# 75%                                   NaN   196.190000    0.270000
# max                                   NaN  1169.576000    2.709200
#
#            Prev NAV     Quantity  Inv. Price   Inv. Date      Inv. Amt  \
# count    283.000000   283.000000  283.000000         283  2.830000e+02
# unique          NaN          NaN         NaN         214           NaN
# top             NaN          NaN         NaN  19-04-2022           NaN
# freq            NaN          NaN         NaN           6           NaN
# mean     171.618673   601.832530  108.403876         NaN  2.363997e+04
# std      261.006283  1114.875882  174.336360         NaN  8.058468e+04
# min       11.972200     0.000000    0.000000         NaN  0.000000e+00
# 25%       25.539000    79.079000   15.994500         NaN  5.000009e+03
# 50%       30.012800   420.345000   22.142200         NaN  9.999996e+03
# 75%      195.920000   538.379000   82.935400         NaN  1.000001e+04
# max     1167.460000  8324.176000  725.825800         NaN  1.236178e+06
#
#          52 Wk High/Low  Todays Gain  Todays Gain%  Overall Gain  \
# count               283   283.000000    283.000000  2.830000e+02
# unique               37          NaN           NaN           NaN
# top     739.05 / 547.28          NaN           NaN           NaN
# freq                 33          NaN           NaN           NaN
# mean                NaN   114.190813      0.223145  1.941895e+04
# std                 NaN   397.935950      0.255674  9.833326e+04
# min                 NaN  -124.000000     -0.510000 -3.670000e+02
# 25%                 NaN     9.000000      0.130000  1.341000e+03
# 50%                 NaN    32.000000      0.260000  4.076000e+03
# 75%                 NaN    64.500000      0.390000  7.141500e+03
# max                 NaN  5090.000000      0.850000  1.577256e+06
#
#         Overall Gain%  Realised Gains  Latest Value Broker Notes
# count      283.000000             0.0  2.830000e+02    283   283
# unique            NaN             NaN           NaN      2     3
# top               NaN             NaN           NaN      -     -
# freq              NaN             NaN           NaN    281   281
# mean        55.545265             NaN  4.305893e+04    NaN   NaN
# std         60.188546             NaN  1.773625e+05    NaN   NaN
# min         -7.350000             NaN  0.000000e+00    NaN   NaN
# 25%         22.155000             NaN  6.865000e+03    NaN   NaN
# 50%         42.070000             NaN  1.411100e+04    NaN   NaN
# 75%         63.775000             NaN  1.714150e+04    NaN   NaN
# max        346.660000             NaN  2.813434e+06    NaN   NaN

# %%
# mf.pivot_table(index='', )

# %%
mf = pd.DataFrame(mf, columns=['Scheme','Inv.Amt','Overall Gain','Inv.Date'])
mf.groupby(['Scheme']).sum()
# Out:
#                                           Inv.Amt  Overall Gain  Inv.Date
# Scheme
# ABSL Frontline Eqty-Direct (G)                0.0        367562       0.0
# ABSL Liquid Fund - D (G)                      0.0          1642       0.0
# BNP Enhanced Equity Hybrid - D (G)            0.0         50372       0.0
# Bandhan Government Securities Fund-IP -D      0.0        172498       0.0
# CR Bluechip Equity Fund - D (G)               0.0        182432       0.0
# DSP Equity Opportunities - Direct (G)         0.0         38133       0.0
# Franklin (I) Bluechip - Direct (G)            0.0        265739       0.0
# HDFC Balanced Advantage Fund-DP-(G)           0.0        190883       0.0
# HDFC Dividend Yield Fund - DP - (D)           0.0         20580       0.0
# HDFC Dividend Yield Fund - DP - (G)           0.0        298815       0.0
# HDFC MidCap Opport.- Direct (G)               0.0        252607       0.0
# HDFC Top 100 Fund - D (G)                     0.0       1577256       0.0
# ICICI Pru All Seasons Bond - D (G)            0.0         33324       0.0
# ICICI Pru Banking & Finserv - D (G)           0.0         83695       0.0
# ICICI Pru Multi-Asset Fund - D(G)             0.0        257448       0.0
# ICICI Pru Technology Fund - D (G)             0.0         23817       0.0
# ICICI Prudential Equity & Debt - D (G)        0.0         63337       0.0
# ICICI Prudential Nifty IT Index Fund-DP-      0.0          3742       0.0
# ICICI Prudential Nifty Pharma Index Fund      0.0         12225       0.0
# Kotak Gold Fund - Direct (G)                  0.0         90227       0.0
# Kotak Nifty Next 50 Index Fund - DP - (G      0.0        153366       0.0
# Kotak Small Cap Fund - D (G)                  0.0         63582       0.0
# Motilal Oswal Nifty Smallcap 250 Index F      0.0         70071       0.0
# Navi Nifty 50 Index Fund - DP - (G)           0.0         14010       0.0
# Nippon Gold Savings - Direct (G)              0.0        117698       0.0
# PGIM India Flexi Cap Fund - DP (G)            0.0         35920       0.0
# PPFAS FCF -DP - (G)                           0.0         57419       0.0
# Quant Absolute Fund - Direct (G)              0.0        120358       0.0
# Quant Multi Asset Fund - DP (G)               0.0         91376       0.0
# Quant Small Cap Fund - DP - (G)               0.0         33475       0.0
# SBI - ETF Gold                                0.0         17741       0.0
# SBI Contra Fund - Direct (G)                  0.0        127559       0.0
# Tata India Pharma & HealthCare -Dir (G)       0.0         98926       0.0
# UTI Core Equity Fund - D (G)                  0.0         73747       0.0
# UTI Dividend Yield Fund -Direct (D)           0.0        173797       0.0
# UTI Mid Cap (G)                               0.0        197012       0.0

# %%
mf.
# Out:
#   Cell In[6], line 1
#     mf.
#        ^
# SyntaxError: invalid syntax
